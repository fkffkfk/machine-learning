# %%
# !conda install --y openpyxl
# Out:
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
# Retrieving notices: ...working... done
# ==> WARNING: A newer version of conda exists. <==
#   current version: 22.9.0
#   latest version: 23.3.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda

# %%
import pandas as pd
import numpy as np
df=pd.read_excel("C:/Users/user/Downloads/excel-comp-data.xlsx")
df
## \ -> / ##
# Out:
#     account                              name  \
# 0    211829        Kerluke, Koepp and Hilpert
# 1    320563                    Walter-Trantow
# 2    648336        Bashirian, Kunde and Price
# 3    109996       D'Amore, Gleichner and Bode
# 4    121213                     Bauch-Goldner
# 5    132971  Williamson, Schumm and Hettinger
# 6    145068                        Casper LLC
# 7    205217                  Kovacek-Johnston
# 8    209744                    Champlin-Morar
# 9    212303                    Gerhold-Maggio
# 10   214098       Goodwin, Homenick and Jerde
# 11   231907                        Hahn-Moore
# 12   242368      Frami, Anderson and Donnelly
# 13   268755                       Walsh-Haley
# 14   273274                     McDermott PLC
#
#                                   street               city          state  \
# 0                     34456 Sean Highway         New Jaycob          Texas
# ...

# %%
df.head(5).T
# Out:
#                                       0                  1  \
# account                          211829             320563
# name         Kerluke, Koepp and Hilpert     Walter-Trantow
# street               34456 Sean Highway  1311 Alvis Tunnel
# city                         New Jaycob      Port Khadijah
# state                             Texas      NorthCarolina
# postal-code                       28752              38365
# Jan                               10000              95000
# Feb                               62000              45000
# Mar                               35000              35000
#
#                                                 2  \
# account                                    648336
# name                   Bashirian, Kunde and Price
# street       62184 Schamberger Underpass Apt. 231
# city                               New Lilianland
# state                                        Iowa
# postal-code                                 76517
# ...

# %%
df[['name','account','street']].head(3)
# Out:
#                          name  account                                street
# 0  Kerluke, Koepp and Hilpert   211829                    34456 Sean Highway
# 1              Walter-Trantow   320563                     1311 Alvis Tunnel
# 2  Bashirian, Kunde and Price   648336  62184 Schamberger Underpass Apt. 231

# %%
df[:3]
# Out:
#    account                        name                                street  \
# 0   211829  Kerluke, Koepp and Hilpert                    34456 Sean Highway
# 1   320563              Walter-Trantow                     1311 Alvis Tunnel
# 2   648336  Bashirian, Kunde and Price  62184 Schamberger Underpass Apt. 231
#
#              city          state  postal-code    Jan     Feb    Mar
# 0      New Jaycob          Texas        28752  10000   62000  35000
# 1   Port Khadijah  NorthCarolina        38365  95000   45000  35000
# 2  New Lilianland           Iowa        76517  91000  120000  35000

# %%
df[["name","street"]][:2]
# Out:
#                                name              street
# account
# 211829   Kerluke, Koepp and Hilpert  34456 Sean Highway
# 320563               Walter-Trantow   1311 Alvis Tunnel

# %%
df_new=df.reset_index()

# %%
df_new
# Out:
#     account                              name  \
# 0    211829        Kerluke, Koepp and Hilpert
# 1    320563                    Walter-Trantow
# 2    648336        Bashirian, Kunde and Price
# 3    109996       D'Amore, Gleichner and Bode
# 4    121213                     Bauch-Goldner
# 5    132971  Williamson, Schumm and Hettinger
# 6    145068                        Casper LLC
# 7    205217                  Kovacek-Johnston
# 8    209744                    Champlin-Morar
# 9    212303                    Gerhold-Maggio
# 10   214098       Goodwin, Homenick and Jerde
# 11   231907                        Hahn-Moore
# 12   242368      Frami, Anderson and Donnelly
# 13   268755                       Walsh-Haley
# 14   273274                     McDermott PLC
#
#                                   street               city          state  \
# 0                     34456 Sean Highway         New Jaycob          Texas
# ...

# %%
df_new.index=df["name"]
del df_new["name"]
df_new.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\ml\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\envs\ml\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\envs\ml\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'name'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df=df_new.reset_index()

# %%
df
# Out:
#                                 name  account  \
# 0         Kerluke, Koepp and Hilpert   211829
# 1                     Walter-Trantow   320563
# 2         Bashirian, Kunde and Price   648336
# 3        D'Amore, Gleichner and Bode   109996
# 4                      Bauch-Goldner   121213
# 5   Williamson, Schumm and Hettinger   132971
# 6                         Casper LLC   145068
# 7                   Kovacek-Johnston   205217
# 8                     Champlin-Morar   209744
# 9                     Gerhold-Maggio   212303
# 10       Goodwin, Homenick and Jerde   214098
# 11                        Hahn-Moore   231907
# 12      Frami, Anderson and Donnelly   242368
# 13                       Walsh-Haley   268755
# 14                     McDermott PLC   273274
#
#                                   street               city          state  \
# 0                     34456 Sean Highway         New Jaycob          Texas
# ...

# %%
df.index=df["name"]
del df["name"]
df.head()
# Out:
#                              account                                street  \
# name
# Kerluke, Koepp and Hilpert    211829                    34456 Sean Highway
# Walter-Trantow                320563                     1311 Alvis Tunnel
# Bashirian, Kunde and Price    648336  62184 Schamberger Underpass Apt. 231
# D'Amore, Gleichner and Bode   109996           155 Fadel Crescent Apt. 144
# Bauch-Goldner                 121213                   7274 Marissa Common
#
#                                         city          state  postal-code  \
# name
# Kerluke, Koepp and Hilpert        New Jaycob          Texas        28752
# Walter-Trantow                 Port Khadijah  NorthCarolina        38365
# Bashirian, Kunde and Price    New Lilianland           Iowa        76517
# D'Amore, Gleichner and Bode       Hyattburgh          Maine        46021
# Bauch-Goldner                Shanahanchester     California        49681
#
#                                 Jan     Feb    Mar
# name
# ...

# %%
df=df_new.reset_index()

# %%
df.index=df["name"]
del df["name"]

# %%
df
# Out:
#                                   account  \
# name
# Kerluke, Koepp and Hilpert         211829
# Walter-Trantow                     320563
# Bashirian, Kunde and Price         648336
# D'Amore, Gleichner and Bode        109996
# Bauch-Goldner                      121213
# Williamson, Schumm and Hettinger   132971
# Casper LLC                         145068
# Kovacek-Johnston                   205217
# Champlin-Morar                     209744
# Gerhold-Maggio                     212303
# Goodwin, Homenick and Jerde        214098
# Hahn-Moore                         231907
# Frami, Anderson and Donnelly       242368
# Walsh-Haley                        268755
# McDermott PLC                      273274
#
#                                                                 street  \
# name
# Kerluke, Koepp and Hilpert                          34456 Sean Highway
# Walter-Trantow                                       1311 Alvis Tunnel
# ...
